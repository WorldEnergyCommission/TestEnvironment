# %% [markdown]
# # Get Error of EMS Predictions
#
# 1. Get all models
# 2. Train model
# 3. Predict on testset
# 4. Calc Errors

# %% [markdown]
# ## Notebook Preps

# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext dotenv
# %dotenv
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %%
# change current directory to the project directory
import os
os.chdir('../../../')

# %%
# !pip install -r ai/requirements.txt --user
#!pip install plotly
#!pip install matplotlib
#!pip install seaborn
# !pip install python-dotenv
# Out:
# Collecting apscheduler==3.10.4
#   Using cached APScheduler-3.10.4-py3-none-any.whl (59 kB)
# Collecting cvxopt==1.3.2
#   Using cached cvxopt-1.3.2-cp311-cp311-win_amd64.whl (12.8 MB)
# Collecting deadpool-executor==2023.7.6
#   Using cached deadpool_executor-2023.7.6-py2.py3-none-any.whl (28 kB)
# Collecting dill==0.3.7
#   Using cached dill-0.3.7-py3-none-any.whl (115 kB)
# Requirement already satisfied: gekko==1.0.6 in c:\users\jpeff\appdata\roaming\python\python311\site-packages (from -r ai/requirements.txt (line 5)) (1.0.6)
# Collecting holidays==0.35
#   Using cached holidays-0.35-py3-none-any.whl (800 kB)
# Collecting minio==7.1.17
#   Using cached minio-7.1.17-py3-none-any.whl (78 kB)
# Collecting mypy==1.6.1
#   Using cached mypy-1.6.1-cp311-cp311-win_amd64.whl (9.0 MB)
# Requirement already satisfied: numpy==1.26.1 in c:\users\jpeff\appdata\roaming\python\python311\site-packages (from -r ai/requirements.txt (line 9)) (1.26.1)
# Collecting optuna==3.3.0
#   Using cached optuna-3.3.0-py3-none-any.whl (404 kB)
# Requirement already satisfied: paho-mqtt==1.6.1 in c:\python311\lib\site-packages (from -r ai/requirements.txt (line 11)) (1.6.1)
# Collecting pandas-stubs==2.1.1.230928
#   Using cached pandas_stubs-2.1.1.230928-py3-none-any.whl (153 kB)
# Collecting pandas==2.1.1
#   Using cached pandas-2.1.1-cp311-cp311-win_amd64.whl (10.6 MB)
# Collecting paramiko==3.3.1
#   Using cached paramiko-3.3.1-py3-none-any.whl (224 kB)
# Requirement already satisfied: psutil==5.9.6 in c:\users\jpeff\appdata\roaming\python\python311\site-packages (from -r ai/requirements.txt (line 15)) (5.9.6)
# Requirement already satisfied: psycopg[binary,pool]==3.1.12 in c:\users\jpeff\appdata\roaming\python\python311\site-packages (from -r ai/requirements.txt (line 16)) (3.1.12)
# Requirement already satisfied: pytz==2023.3.post1 in c:\users\jpeff\appdata\roaming\python\python311\site-packages (from -r ai/requirements.txt (line 17)) (2023.3.post1)
# Requirement already satisfied: requests==2.31.0 in c:\users\jpeff\appdata\roaming\python\python311\site-packages (from -r ai/requirements.txt (line 18)) (2.31.0)
# Collecting rrcf==0.4.4
#   Using cached rrcf-0.4.4-py3-none-any.whl
# Requirement already satisfied: sanic-cors==2.2.0 in c:\users\jpeff\appdata\roaming\python\python311\site-packages (from -r ai/requirements.txt (line 20)) (2.2.0)
# Collecting sanic==23.6.0
#   Using cached sanic-23.6.0-py3-none-any.whl (202 kB)
# Collecting scikit-learn==1.3.1
#   Using cached scikit_learn-1.3.1-cp311-cp311-win_amd64.whl (9.2 MB)
# Requirement already satisfied: scipy==1.11.3 in c:\users\jpeff\appdata\roaming\python\python311\site-packages (from -r ai/requirements.txt (line 23)) (1.11.3)
# Requirement already satisfied: simple-pid==2.0.0 in c:\users\jpeff\appdata\roaming\python\python311\site-packages (from -r ai/requirements.txt (line 24)) (2.0.0)
# Requirement already satisfied: six==1.16.0 in c:\users\jpeff\appdata\roaming\python\python311\site-packages (from -r ai/requirements.txt (line 25)) (1.16.0)
# Requirement already satisfied: types-paho-mqtt==1.6.0.7 in c:\users\jpeff\appdata\roaming\python\python311\site-packages (from -r ai/requirements.txt (line 26)) (1.6.0.7)
# Collecting types-paramiko==3.3.0.0
#   Using cached types_paramiko-3.3.0.0-py3-none-any.whl (33 kB)
# Requirement already satisfied: types-pytz==2023.3.1.1 in c:\users\jpeff\appdata\roaming\python\python311\site-packages (from -r ai/requirements.txt (line 28)) (2023.3.1.1)
# Requirement already satisfied: types-requests==2.31.0.10 in c:\users\jpeff\appdata\roaming\python\python311\site-packages (from -r ai/requirements.txt (line 29)) (2.31.0.10)
# Requirement already satisfied: types-urllib3==1.26.25.14 in c:\users\jpeff\appdata\roaming\python\python311\site-packages (from -r ai/requirements.txt (line 30)) (1.26.25.14)
# Requirement already satisfied: urllib3==2.0.7 in c:\users\jpeff\appdata\roaming\python\python311\site-packages (from -r ai/requirements.txt (line 31)) (2.0.7)
# Collecting xgboost==2.0.0
#   Using cached xgboost-2.0.0-py3-none-win_amd64.whl (99.7 MB)
# Requirement already satisfied: tzlocal!=3.*,>=2.0 in c:\users\jpeff\appdata\roaming\python\python311\site-packages (from apscheduler==3.10.4->-r ai/requirements.txt (line 1)) (5.0.1)
# Requirement already satisfied: python-dateutil in c:\users\jpeff\appdata\roaming\python\python311\site-packages (from holidays==0.35->-r ai/requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: certifi in c:\python311\lib\site-packages (from minio==7.1.17->-r ai/requirements.txt (line 7)) (2023.5.7)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\python311\lib\site-packages (from mypy==1.6.1->-r ai/requirements.txt (line 8)) (4.5.0)
# Requirement already satisfied: mypy-extensions>=1.0.0 in c:\python311\lib\site-packages (from mypy==1.6.1->-r ai/requirements.txt (line 8)) (1.0.0)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\jpeff\appdata\roaming\python\python311\site-packages (from optuna==3.3.0->-r ai/requirements.txt (line 10)) (1.11.1)
# Collecting cmaes>=0.10.0
#   Using cached cmaes-0.10.0-py3-none-any.whl (29 kB)
# Requirement already satisfied: colorlog in c:\users\jpeff\appdata\roaming\python\python311\site-packages (from optuna==3.3.0->-r ai/requirements.txt (line 10)) (6.7.0)
# Requirement already satisfied: packaging>=20.0 in c:\python311\lib\site-packages (from optuna==3.3.0->-r ai/requirements.txt (line 10)) (23.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in c:\users\jpeff\appdata\roaming\python\python311\site-packages (from optuna==3.3.0->-r ai/requirements.txt (line 10)) (2.0.18)
# Requirement already satisfied: tqdm in c:\python311\lib\site-packages (from optuna==3.3.0->-r ai/requirements.txt (line 10)) (4.65.0)
# Requirement already satisfied: PyYAML in c:\python311\lib\site-packages (from optuna==3.3.0->-r ai/requirements.txt (line 10)) (6.0)
# Requirement already satisfied: tzdata>=2022.1 in c:\python311\lib\site-packages (from pandas==2.1.1->-r ai/requirements.txt (line 13)) (2023.3)
# Requirement already satisfied: bcrypt>=3.2 in c:\users\jpeff\appdata\roaming\python\python311\site-packages (from paramiko==3.3.1->-r ai/requirements.txt (line 14)) (4.0.1)
# Requirement already satisfied: cryptography>=3.3 in c:\users\jpeff\appdata\roaming\python\python311\site-packages (from paramiko==3.3.1->-r ai/requirements.txt (line 14)) (41.0.1)
# Requirement already satisfied: pynacl>=1.5 in c:\users\jpeff\appdata\roaming\python\python311\site-packages (from paramiko==3.3.1->-r ai/requirements.txt (line 14)) (1.5.0)
# Requirement already satisfied: psycopg-binary==3.1.12 in c:\users\jpeff\appdata\roaming\python\python311\site-packages (from psycopg[binary,pool]==3.1.12->-r ai/requirements.txt (line 16)) (3.1.12)
# Requirement already satisfied: psycopg-pool in c:\users\jpeff\appdata\roaming\python\python311\site-packages (from psycopg[binary,pool]==3.1.12->-r ai/requirements.txt (line 16)) (3.1.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python311\lib\site-packages (from requests==2.31.0->-r ai/requirements.txt (line 18)) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\python311\lib\site-packages (from requests==2.31.0->-r ai/requirements.txt (line 18)) (3.4)
# Requirement already satisfied: sanic-routing>=23.6.0 in c:\users\jpeff\appdata\roaming\python\python311\site-packages (from sanic==23.6.0->-r ai/requirements.txt (line 21)) (23.12.0)
# Requirement already satisfied: httptools>=0.0.10 in c:\users\jpeff\appdata\roaming\python\python311\site-packages (from sanic==23.6.0->-r ai/requirements.txt (line 21)) (0.5.0)
# Requirement already satisfied: aiofiles>=0.6.0 in c:\users\jpeff\appdata\roaming\python\python311\site-packages (from sanic==23.6.0->-r ai/requirements.txt (line 21)) (23.1.0)
# Requirement already satisfied: websockets>=10.0 in c:\python311\lib\site-packages (from sanic==23.6.0->-r ai/requirements.txt (line 21)) (11.0.3)
# Requirement already satisfied: multidict<7.0,>=5.0 in c:\users\jpeff\appdata\roaming\python\python311\site-packages (from sanic==23.6.0->-r ai/requirements.txt (line 21)) (6.0.4)
# Requirement already satisfied: html5tagger>=1.2.1 in c:\users\jpeff\appdata\roaming\python\python311\site-packages (from sanic==23.6.0->-r ai/requirements.txt (line 21)) (1.3.0)
# Requirement already satisfied: tracerite>=1.0.0 in c:\users\jpeff\appdata\roaming\python\python311\site-packages (from sanic==23.6.0->-r ai/requirements.txt (line 21)) (1.1.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\jpeff\appdata\roaming\python\python311\site-packages (from scikit-learn==1.3.1->-r ai/requirements.txt (line 22)) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\jpeff\appdata\roaming\python\python311\site-packages (from scikit-learn==1.3.1->-r ai/requirements.txt (line 22)) (3.1.0)
# Requirement already satisfied: Mako in c:\users\jpeff\appdata\roaming\python\python311\site-packages (from alembic>=1.5.0->optuna==3.3.0->-r ai/requirements.txt (line 10)) (1.2.4)
# Requirement already satisfied: cffi>=1.12 in c:\users\jpeff\appdata\roaming\python\python311\site-packages (from cryptography>=3.3->paramiko==3.3.1->-r ai/requirements.txt (line 14)) (1.15.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\jpeff\appdata\roaming\python\python311\site-packages (from sqlalchemy>=1.3.0->optuna==3.3.0->-r ai/requirements.txt (line 10)) (2.0.2)
# Requirement already satisfied: colorama in c:\python311\lib\site-packages (from colorlog->optuna==3.3.0->-r ai/requirements.txt (line 10)) (0.4.6)
# Requirement already satisfied: pycparser in c:\users\jpeff\appdata\roaming\python\python311\site-packages (from cffi>=1.12->cryptography>=3.3->paramiko==3.3.1->-r ai/requirements.txt (line 14)) (2.21)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\python311\lib\site-packages (from Mako->alembic>=1.5.0->optuna==3.3.0->-r ai/requirements.txt (line 10)) (2.1.2)
# Installing collected packages: rrcf, pandas-stubs, mypy, minio, dill, deadpool-executor, cvxopt, cmaes, xgboost, scikit-learn, sanic, pandas, holidays, apscheduler, types-paramiko, paramiko, optuna
#   Attempting uninstall: rrcf
#     Found existing installation: rrcf 0.4.3
#     Uninstalling rrcf-0.4.3:
#       Successfully uninstalled rrcf-0.4.3
#   Attempting uninstall: pandas-stubs
#     Found existing installation: pandas-stubs 1.5.3.230321
#     Uninstalling pandas-stubs-1.5.3.230321:
#       Successfully uninstalled pandas-stubs-1.5.3.230321
#   Attempting uninstall: mypy
#     Found existing installation: mypy 1.2.0
#     Uninstalling mypy-1.2.0:
#       Successfully uninstalled mypy-1.2.0
#   Attempting uninstall: minio
#     Found existing installation: minio 7.1.14
#     Uninstalling minio-7.1.14:
#       Successfully uninstalled minio-7.1.14
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.6
#     Uninstalling dill-0.3.6:
#       Successfully uninstalled dill-0.3.6
#   Attempting uninstall: cvxopt
#     Found existing installation: cvxopt 1.3.0
#     Uninstalling cvxopt-1.3.0:
#       Successfully uninstalled cvxopt-1.3.0
#   Attempting uninstall: cmaes
#     Found existing installation: cmaes 0.9.1
#     Uninstalling cmaes-0.9.1:
#       Successfully uninstalled cmaes-0.9.1
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 1.7.5
#     Uninstalling xgboost-1.7.5:
#       Successfully uninstalled xgboost-1.7.5
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\jpeff\\AppData\\Roaming\\Python\\Python311\\site-packages\\~gboost\\lib\\xgboost.dll'
# Check the permissions.
#
#
# [notice] A new release of pip available: 22.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: python-dotenv in c:\python311\lib\site-packages (1.0.0)
# [notice] A new release of pip available: 22.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# First let's set environment variables. (in .env file in ai folder) (Note: also run the proxy script) Example would be
#
# ```env
# CLUSTER_NAME=dev
# DB_USER=asdf
# DB_PASS=asdf
# DB_ADDR=127.0.0.1
# DB_PORT=5432
# DB_NAME=lynus
# DB_MODE=disable
# S3_ENDPOINT=sos-at-vie-1.exo.io
# S3_ACCESS_KEY=asdf
# S3_SECRET_KEY=asdf
# S3_SECURE=1
# EMPA_ADDR=http://127.0.0.1:9000/
# WEATHER_API_KEY=asdf
# ```

# %%
from dotenv import load_dotenv

load_dotenv("./ai/.env.bms", override=True)
# Out:
# True

# %% [markdown]
# ## EMS Testing

# %% [markdown]
# ### Fetch all Models

# %%
import psycopg
import pandas as pd

# Get DB connection and all EMS models

try:
    # Establish a connection to the PostgreSQL database
    connection = psycopg.connect(
        dbname=os.environ["DB_NAME"],
        user=os.environ["DB_USER"],
        password=os.environ["DB_PASS"],
        host=os.environ["DB_ADDR"],
        port=os.environ["DB_PORT"]
    )

    # Create a cursor object to interact with the database
    cursor = connection.cursor()

    cursor.execute("SELECT models.id as model_id, models.r->'data'->>'type' as model_type, project.name as project_name, models.r->>'project_id' as project_id \
FROM models \
JOIN project ON models.r->>'project_id'= project.id::text \
WHERE models.r -> 'data' ->> 'type' LIKE '%EMS%' \
")
    result = cursor.fetchall()
    columns = [desc[0] for desc in cursor.description]  # Get column names
    

except psycopg.Error as e:
    print(f"Unable to connect to the database. Error: {e}")

finally:
    # Close the cursor and connection, regardless of whether the try block succeeds or raises an exception
    if connection:
        cursor.close()
        connection.close()
        print("Connection closed.")

# Convert the result to a Pandas DataFrame
model_df = pd.DataFrame(result, columns=columns)
model_df
# Out:
# Connection closed.
#                                 model_id model_type  \
# 0   d9cdab3e-acd9-499b-b53c-05d698b23b95        EMS
# 1   a2281880-cb84-4705-a09d-f80367bdd342        EMS
# 2   0ed1bfca-b33e-4063-a907-d5ebe85bb622        EMS
# 3   4d908d4d-b57d-47e8-ab5a-738326e72be9        EMS
# 4   660decfe-1fe8-4c3d-b6ea-f29d22697d94        EMS
# 5   9d79ac11-63df-45ad-82a2-0075652d0506        EMS
# 6   99582f62-bad3-4bbb-8ff6-42d9f0827a1f        EMS
# 7   15334478-785b-4345-8a88-cc748e9abcb7        EMS
# 8   fd2f03d2-099b-45e3-b300-b01853e06f00        EMS
# 9   d1793fbb-e453-4a38-a37d-235e0111afe1        EMS
# 10  e66af47b-9aa9-45dd-ac55-cc6b242ccb9b        EMS
# 11  13a48710-44cc-4bd1-ad5c-96a93c599860        EMS
# 12  920b11c1-cd65-496d-8ff4-f248a545c106        EMS
#
#                     project_name                            project_id
# 0          Projekt Hammerschmied  673dfecd-87ae-41b4-adc6-bf4a9ec1d31b
# 1                      Mayrhofer  e51c2607-26db-4106-b5ea-e880014dacba
# 2                  Barac Michael  c4f8afbf-2040-4517-95e7-ed7f0d999242
# 3                           HAPU  b818e25e-2206-4375-bd9d-0099f6e8c3ab
# 4                           HAPU  b818e25e-2206-4375-bd9d-0099f6e8c3ab
# 5                          Feigl  f2612c04-11b1-4280-957b-bcd7afeefd1d
# 6                 Projekt Kogler  f78d81b3-e56c-4072-b5bd-ca591893463c
# 7                      Jodlbauer  189e4327-6e6d-4ffb-9c03-09f2cb3fc9e8
# 8                       Brandmoa  32673a79-600a-4644-a67c-4e88e91f75b0
# 9            Projekt Katzenhofer  9c801c0d-8c2c-4278-a890-f6835690b001
# 10   Projekt Reichinger Katsdorf  728932ac-dc47-4305-9677-d9533ba4a462
# 11        Projekt Kofler Maurach  34467fe1-3b9d-4cc2-8cff-1c321ed830b0
# 12  PTM Kunstofftechnologie GmbH  a77d1054-48f1-4ad6-a5da-3c6ee387acdf

# %% [markdown]
# ### Functions used in this Notebook

# %%
import datetime
from ai.model.ems_model import EmsModel
from ai.preprocessing.ems_preprocessing import preprocess_ems_data, get_ems_features
from ai.interface.model_holder import ModelHolder
from ai.model_holder.ems_model_holder import EmsModelHolder

# Get start and end time to create train and test set


index = 2
train_duration_weeks = 5

model_id = str(model_df.iloc[index]["model_id"])
model_holder_type = EmsModelHolder
model_holder = ModelHolder.load_model_holder_from_s3(model_id, model_holder_type, model_load=False)

end = datetime.datetime.now()
start = datetime.datetime.fromtimestamp(model_holder.get_start())

if (end - start) <= datetime.timedelta(days=14):
    raise ValueError("Too few data (< 14 days) for EMS training!")

if end - start > datetime.timedelta(weeks=train_duration_weeks):
    start = end - datetime.timedelta(weeks=train_duration_weeks)            
end_training = end - datetime.timedelta(weeks=1)

df = model_holder.get_dh().get_data(int(start.timestamp()), int(end_training.timestamp()))
df = preprocess_ems_data(df, 15, True)

(x, y_consumption, y_pv, y_generator, y_grid, y_battery,
        y_charge, y_house, y_electric, y_pump, y_consumer,
        y_soc, y_tpow_battery, y_tpow_charge, y_tpow_electric, y_tpow_pump,
        y_tpow_consumer, recursive) = get_ems_features(
        df,
        lag_steps=[15, 30, 45, 60],
        prediction_steps=[15, 30, 45, 60],
        time_resolution=15,
        lag_label=[15])


import seaborn as sns
import matplotlib.pyplot as plt

palette = [
'#03e0b5',
'#24AD92',
'#327A6C',
'#2C4742',
'#293331',]

# Plot errors
def plot_errors(error_dict, prefix):
    fig, axes = plt.subplots(nrows=1, ncols=len(error_dict), figsize=(18, 6), sharey=False)
    for i, (key, value) in enumerate(error_dict.items()):
        
        # Extract keys and values from the dictionary
        model_names = list(value.keys())
        errors = list(value.values())

        # Create a bar chart using seaborn
        sns.set(style="white")
        plt.figure(figsize=(10, 6))
        axes[i].set_title(f'{model_df.iloc[index]["project_name"]} {key} {train_duration_weeks}-weeks')

        ax = sns.barplot(x=model_names, ax=axes[i], y=errors, palette=palette, hue=errors)
        ax.legend_.remove()
        ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
        for p in ax.patches:
            if p.get_width() == p.get_height() == 0:
                continue
            
            ax.text(p.get_x() + p.get_width()/2., p.get_height(), '{0:.2f}'.format(p.get_height()), 
            fontsize=12, color=p.get_facecolor(), ha='center', va='bottom')

    fig.savefig(f"{prefix}_{model_df.iloc[index]['project_name']}_{model_df.iloc[index]['model_id']}_dur-{train_duration_weeks}.png")
    return fig

# %% [markdown]
# ### Benchmarking

# %% [markdown]
# #### Current EMS

# %%
# Fit model
from ai.model.ems_model import EmsModel
model_rf = EmsModel()
model_rf.fit(x, y_consumption, y_pv, y_generator, y_grid, y_battery, y_charge,
            y_house, y_electric, y_pump, y_consumer, y_soc, y_tpow_battery,
            y_tpow_charge, y_tpow_electric, y_tpow_pump, y_tpow_consumer, recursive)

# %%
df_eval = model_holder.get_dh().get_data(
                int(end_training.timestamp()), int(end.timestamp()))
errors_rf = model_rf.evaluate(df_eval)

# %%
plot_rf = plot_errors(errors_rf, "RF")
# Out:
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_13760\1660128550.py:65: UserWarning:
# The palette list has fewer values (5) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   ax = sns.barplot(x=model_names, ax=axes[i], y=errors, palette=palette, hue=errors)
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_13760\1660128550.py:67: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_13760\1660128550.py:65: UserWarning:
# The palette list has fewer values (5) than needed (8) and will cycle, which may produce an uninterpretable plot.
#   ax = sns.barplot(x=model_names, ax=axes[i], y=errors, palette=palette, hue=errors)
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_13760\1660128550.py:67: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')

# %% [markdown]
# #### XGBoost

# %%
# trying xgboost
import xgboost as xgb
# Fit model
model_xg = EmsModel(custom_regressor=xgb.XGBRegressor, custom_regressor_args={"objective":"reg:squarederror", "random_state":42})
model_xg.fit(x, y_consumption, y_pv, y_generator, y_grid, y_battery, y_charge,
            y_house, y_electric, y_pump, y_consumer, y_soc, y_tpow_battery,
            y_tpow_charge, y_tpow_electric, y_tpow_pump, y_tpow_consumer, recursive)

# %%
errors_xg = model_xg.evaluate(df_eval)
plot_xg = plot_errors(errors_xg, "XG")
# Out:
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_13760\1660128550.py:65: UserWarning:
# The palette list has fewer values (5) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   ax = sns.barplot(x=model_names, ax=axes[i], y=errors, palette=palette, hue=errors)
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_13760\1660128550.py:67: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_13760\1660128550.py:65: UserWarning:
# The palette list has fewer values (5) than needed (8) and will cycle, which may produce an uninterpretable plot.
#   ax = sns.barplot(x=model_names, ax=axes[i], y=errors, palette=palette, hue=errors)
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_13760\1660128550.py:67: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')

# %% [markdown]
# #### Current Implemented Recurrent Random Forest (w XGB)

# %%
# Fit model
model_rxg = EmsModel(model_type=1)
model_rxg.fit(x, y_consumption, y_pv, y_generator, y_grid, y_battery, y_charge,
            y_house, y_electric, y_pump, y_consumer, y_soc, y_tpow_battery,
            y_tpow_charge, y_tpow_electric, y_tpow_pump, y_tpow_consumer, recursive)
# Out:
# C:\Users\jpeff\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:885: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\jpeff\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\jpeff\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:885: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\jpeff\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\jpeff\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:885: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\jpeff\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\jpeff\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:885: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\jpeff\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\jpeff\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:885: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\jpeff\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\jpeff\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:885: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\jpeff\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\jpeff\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:885: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\jpeff\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\jpeff\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:885: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\jpeff\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(

# %%
errors_rxg = model_rxg.evaluate(df_eval)
plot_rxg = plot_errors(errors_rxg, "RXG")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\jpeff\Documents\GitHub\efficientIO\ai\notebooks\ems\howDoesEMSworkBetter copy.ipynb Cell 23 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jpeff/Documents/GitHub/efficientIO/ai/notebooks/ems/howDoesEMSworkBetter%20copy.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> errors_rxg = model_rxg.evaluate(df_eval)
#       <a href='vscode-notebook-cell:/c%3A/Users/jpeff/Documents/GitHub/efficientIO/ai/notebooks/ems/howDoesEMSworkBetter%20copy.ipynb#X31sZmlsZQ%3D%3D?line=1'>2</a> plot_rxg = plot_errors(errors_rxg, "RXG")
#
# File c:\Users\jpeff\Documents\GitHub\efficientIO\ai\model\ems_model.py:235, in EmsModel.evaluate(self, df)
#     222 df = preprocess_ems_data(df, 15, True)
#     223 (x, y_consumption, y_pv, y_generator, y_grid, y_battery,
#     224  y_charge, y_house, y_electric, y_pump, y_consumer,
#     225  y_soc, y_tpow_battery, y_tpow_charge, y_tpow_electric, y_tpow_pump,
#    (...)
#     230     time_resolution=15,
#     231     lag_label=[15])
#     233 (y_consumption_pred, y_pv_pred, y_generator_pred, y_grid_pred, y_battery_pred, y_charge_pred,
#     234  y_house_pred, y_electric_pred, y_pump_pred, y_consumer_pred, y_soc_pred, y_tpow_battery_pred,
# --> 235  y_tpow_charge_pred, y_tpow_electric_pred, y_tpow_pump_pred, y_tpow_consumer_pred) = self.predict(x, recursive)
#     237 # prepare error calcs
#     238 pairs = {
#     239     "y_consumption": (y_consumption, y_consumption_pred),
#     240     "y_pv": (y_pv, y_pv_pred),
#    (...)
#     254     "y_tpow_consumer": (y_tpow_consumer, y_tpow_consumer_pred)
#     255 }
#
# File c:\Users\jpeff\Documents\GitHub\efficientIO\ai\model\ems_model.py:157, in EmsModel.predict(self, x, recursive)
#     150 """predicts the power and target power of the connected components
#     151
#     152 :param x: input features for the prediction
#     153 :param recursive: recursive labels if the model is a recursive one
#     154 """
#     156 if recursive is not None and self.custom_regressor is None:
# --> 157     y_consumption = self.consumption_model.predict(
#     158         x, recursive[self.consumption_model.name])
#     159 else:
#     160     y_consumption = self.consumption_model.predict(x)
#
# File c:\Users\jpeff\Documents\GitHub\efficientIO\ai\utils\recursive_random_forest_utils.py:89, in RecursiveRandomForest.predict(self, x, r)
#      84 for i in range(loop):
#      85     if self.model_type == 1:
#      86         pred = self.model.predict(pd.concat([x.loc[start + pd.to_timedelta(i * 15, 'min')],
#      87                                              r.loc[start + pd.to_timedelta(i * 15, 'min')]]).values.reshape(1,
#      88                                                                                                             -1),
# ---> 89                                   iteration_range=(0, self.model.best_ntree_limit))
#      90     else:
#      91         pred = self.model.predict(
#      92             pd.concat([x.loc[start + pd.to_timedelta(i * 15, 'min')],
#      93                        r.loc[start + pd.to_timedelta(i * 15, 'min')]]).to_frame().transpose())
#
# AttributeError: 'XGBRegressor' object has no attribute 'best_ntree_limit'

# %% [markdown]
# #### Tweedie Regression

# %%
# GLM
from sklearn.linear_model import TweedieRegressor

# Fit model
model_glm = EmsModel(custom_regressor=TweedieRegressor, custom_regressor_args={})
model_glm.fit(x, y_consumption, y_pv, y_generator, y_grid, y_battery, y_charge,
            y_house, y_electric, y_pump, y_consumer, y_soc, y_tpow_battery,
            y_tpow_charge, y_tpow_electric, y_tpow_pump, y_tpow_consumer, recursive)
# Out:
# C:\Users\jpeff\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_glm\glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# C:\Users\jpeff\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_glm\glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# C:\Users\jpeff\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_glm\glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# C:\Users\jpeff\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_glm\glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# C:\Users\jpeff\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_glm\glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# C:\Users\jpeff\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_glm\glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# C:\Users\jpeff\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_glm\glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# C:\Users\jpeff\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_glm\glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)

# %%
errors_glm = model_glm.evaluate(df_eval)
plot_glm = plot_errors(errors_glm, "GLM")
# Out:
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_13760\1660128550.py:65: UserWarning:
# The palette list has fewer values (5) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   ax = sns.barplot(x=model_names, ax=axes[i], y=errors, palette=palette, hue=errors)
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_13760\1660128550.py:67: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_13760\1660128550.py:65: UserWarning:
# The palette list has fewer values (5) than needed (8) and will cycle, which may produce an uninterpretable plot.
#   ax = sns.barplot(x=model_names, ax=axes[i], y=errors, palette=palette, hue=errors)
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_13760\1660128550.py:67: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')

# %% [markdown]
# #### Support Vector Regression

# %%
from sklearn import svm

# Fit model
model_svm = EmsModel(custom_regressor=svm.SVR, custom_regressor_args={})
model_svm.fit(x, y_consumption, y_pv, y_generator, y_grid, y_battery, y_charge,
            y_house, y_electric, y_pump, y_consumer, y_soc, y_tpow_battery,
            y_tpow_charge, y_tpow_electric, y_tpow_pump, y_tpow_consumer, recursive)

# %%
errors_svm = model_svm.evaluate(df_eval)
plot_svm = plot_errors(errors_svm, "SVM")
# Out:
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_13760\1660128550.py:65: UserWarning:
# The palette list has fewer values (5) than needed (8) and will cycle, which may produce an uninterpretable plot.
#   ax = sns.barplot(x=model_names, ax=axes[i], y=errors, palette=palette, hue=errors)
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_13760\1660128550.py:67: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_13760\1660128550.py:65: UserWarning:
# The palette list has fewer values (5) than needed (8) and will cycle, which may produce an uninterpretable plot.
#   ax = sns.barplot(x=model_names, ax=axes[i], y=errors, palette=palette, hue=errors)
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_13760\1660128550.py:67: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')

# %% [markdown]
# #### Elastic Net

# %%
from sklearn.linear_model import ElasticNet

# Fit model
model_elastic = EmsModel(custom_regressor=ElasticNet, custom_regressor_args={})
model_elastic.fit(x, y_consumption, y_pv, y_generator, y_grid, y_battery, y_charge,
            y_house, y_electric, y_pump, y_consumer, y_soc, y_tpow_battery,
            y_tpow_charge, y_tpow_electric, y_tpow_pump, y_tpow_consumer, recursive)
# Out:
# C:\Users\jpeff\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.165e+02, tolerance: 2.877e+01
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\jpeff\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.118e+02, tolerance: 5.179e+00
#   model = cd_fast.enet_coordinate_descent(

# %%
errors_elastic = model_elastic.evaluate(df_eval)
plot_elastic = plot_errors(errors_elastic, "elastic")
# Out:
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_13760\1660128550.py:65: UserWarning:
# The palette list has fewer values (5) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   ax = sns.barplot(x=model_names, ax=axes[i], y=errors, palette=palette, hue=errors)
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_13760\1660128550.py:67: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_13760\1660128550.py:65: UserWarning:
# The palette list has fewer values (5) than needed (8) and will cycle, which may produce an uninterpretable plot.
#   ax = sns.barplot(x=model_names, ax=axes[i], y=errors, palette=palette, hue=errors)
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_13760\1660128550.py:67: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')

# %% [markdown]
# #### Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# Fit model
model_lr = EmsModel(custom_regressor=LinearRegression, custom_regressor_args=[])
model_lr.fit(x, y_consumption, y_pv, y_generator, y_grid, y_battery, y_charge,
            y_house, y_electric, y_pump, y_consumer, y_soc, y_tpow_battery,
            y_tpow_charge, y_tpow_electric, y_tpow_pump, y_tpow_consumer, recursive)

# %%
errors_lr = model_lr.evaluate(df_eval)
plot_lr = plot_errors(errors_lr, "Linear-Regression")
# Out:
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_13760\1660128550.py:65: UserWarning: The palette list has more values (5) than needed (3), which may not be intended.
#   ax = sns.barplot(x=model_names, ax=axes[i], y=errors, palette=palette, hue=errors)
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_13760\1660128550.py:67: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_13760\1660128550.py:65: UserWarning:
# The palette list has fewer values (5) than needed (8) and will cycle, which may produce an uninterpretable plot.
#   ax = sns.barplot(x=model_names, ax=axes[i], y=errors, palette=palette, hue=errors)
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_13760\1660128550.py:67: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')

# %% [markdown]
# ### Testing Pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler

# Fit model
model_std_svr = EmsModel(custom_regressor=Pipeline, custom_regressor_args={"steps":[("scaler", MinMaxScaler()),("svr",svm.SVR())]})

model_std_svr.fit(x, y_consumption, y_pv, y_generator, y_grid, y_battery, y_charge,
            y_house, y_electric, y_pump, y_consumer, y_soc, y_tpow_battery,
            y_tpow_charge, y_tpow_electric, y_tpow_pump, y_tpow_consumer, recursive)

# %%
df_preprocessed_for_prediction = preprocess_ems_data(df_eval, 15, True)
(x_pred, y_consumption_actual, y_pv_actual, _, y_grid_actual, y_battery_actual,
    y_charge_actual, _, _,_, _, y_soc_actual,_, _, _, _,
    _, recursive) = get_ems_features(
    df_preprocessed_for_prediction,
    lag_steps=[15, 30, 45, 60],
    prediction_steps=[15, 30, 45, 60],
    time_resolution=15,
    lag_label=[15])
(y_consumption_pred, y_pv_pred, y_generator_pred, y_grid_pred, y_battery_pred, y_charge_pred,
         y_house_pred, y_electric_pred, y_pump_pred, y_consumer_pred, y_soc_pred, y_tpow_battery_pred,
         y_tpow_charge_pred, y_tpow_electric_pred, y_tpow_pump_pred, y_tpow_consumer_pred)= model_svm.predict(x_pred)

y_consumption_pred.max()
# Out:
# 2.802735663669809

# %%
pv_frame = pd.DataFrame(y_pv_actual).transpose()
#pv_frame.columns = ["Actual"]
pv_frame
# Out:
#                            pv1_power  pv2_power
# ts
# 2024-01-17 16:15:00+01:00   0.009596   0.014263
# 2024-01-17 16:30:00+01:00   0.000024   0.001080
# 2024-01-17 16:45:00+01:00   0.000000   0.000003
# 2024-01-17 17:00:00+01:00   0.000000   0.000000
# 2024-01-17 17:15:00+01:00   0.000000   0.000000
# ...                              ...        ...
# 2024-01-24 13:00:00+01:00   0.018994   0.075055
# 2024-01-24 13:15:00+01:00   0.024547   0.011725
# 2024-01-24 13:30:00+01:00   0.187595   0.017889
# 2024-01-24 13:45:00+01:00   0.209945   0.019995
# 2024-01-24 14:00:00+01:00   0.210000   0.020000
#
# [664 rows x 2 columns]

# %%
pv_frame["Prediction"] = y_pv_pred[0]
pv_frame["Prediction_2"] = y_pv_pred[1]
pv_frame[["Prediction", "pv1_power"]].plot()
# Out:
# <Axes: xlabel='ts'>

# %%
errors_std_svr = model_std_svr.evaluate(df_eval)
plot_std_svr = plot_errors(errors_std_svr, "SVR-Pipeline")
# Out:
# C:\Users\jpeff\AppData\Roaming\Python\Python311\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\jpeff\AppData\Roaming\Python\Python311\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_32596\1776157250.py:65: UserWarning: The palette list has more values (5) than needed (4), which may not be intended.
#   ax = sns.barplot(x=model_names, ax=axes[i], y=errors, palette=palette, hue=errors)
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_32596\1776157250.py:67: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_32596\1776157250.py:65: UserWarning:
# The palette list has fewer values (5) than needed (10) and will cycle, which may produce an uninterpretable plot.
#   ax = sns.barplot(x=model_names, ax=axes[i], y=errors, palette=palette, hue=errors)
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_32596\1776157250.py:67: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')

# %% [markdown]
# ### THE END (more or less)

# %% [markdown]
# exception to stop notebook here

# %%
raise Exception()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# c:\Users\jpeff\Documents\GitHub\efficientIO\ai\notebooks\ems\howDoesEMSworkBetter.ipynb Cell 42 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jpeff/Documents/GitHub/efficientIO/ai/notebooks/ems/howDoesEMSworkBetter.ipynb#Y106sZmlsZQ%3D%3D?line=0'>1</a> raise Exception()
#
# Exception:

# %% [markdown]
# ### Sanity Check

# %%
model_rf.fit(x, y_consumption, y_pv, y_generator, y_grid, y_battery, y_charge,
            y_house, y_electric, y_pump, y_consumer, y_soc, y_tpow_battery,
            y_tpow_charge, y_tpow_electric, y_tpow_pump, y_tpow_consumer, recursive)
# Out:
# Fitting RecursiveRandomForest
# Fittings RF Recursifly
# Fitting RecursiveRandomForest
# Fittings RF Recursifly
# Fitting RecursiveRandomForest
# Fittings RF Recursifly
# Fitting RecursiveRandomForest
# Fittings RF Recursifly
# Fitting RecursiveRandomForest
# Fittings RF Recursifly
# Fitting RecursiveRandomForest
# Fittings RF Recursifly
# Fitting RecursiveRandomForest
# Fittings RF Recursifly
# Fitting RecursiveRandomForest
# Fittings RF Recursifly
# Fitting RecursiveRandomForest
# Fittings RF Recursifly
# Fitting RecursiveRandomForest
# Fittings RF Recursifly
# Fitting RecursiveRandomForest
# Fittings RF Recursifly
# Fitting RecursiveRandomForest
# Fittings RF Recursifly

# %%
# create test set and predict

df_test = model_holder.get_dh().get_data(int(end_training.timestamp()), int(end.timestamp()))
df_test = preprocess_ems_data(df_test, 15, True)

(x, y_consumption, y_pv, y_generator, y_grid, y_battery,
    y_charge, y_house, y_electric, y_pump, y_consumer,
    y_soc, y_tpow_battery, y_tpow_charge, y_tpow_electric, y_tpow_pump,
    y_tpow_consumer, recursive) = get_ems_features(
    df_test,
    lag_steps=[15, 30, 45, 60],
    prediction_steps=[15, 30, 45, 60],
    time_resolution=15,
    lag_label=[15])
    
(y_consumption_pred, y_pv_pred, y_generator_pred, y_grid_pred, y_battery_pred, y_charge_pred,
    y_house_pred, y_electric_pred, y_pump_pred, y_consumer_pred, y_soc_pred, y_tpow_battery_pred,
    y_tpow_charge_pred, y_tpow_electric_pred, y_tpow_pump_pred, y_tpow_consumer_pred) = model_rf.predict(x, recursive)
    
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error, r2_score
import numpy as np

# prepare error calcs
pairs = {
    "y_consumption":(y_consumption,y_consumption_pred),
    "y_pv":(y_pv,y_pv_pred),
    "y_generator":(y_generator,y_generator_pred),
    "y_grid":(y_grid,y_grid_pred),
    "y_battery":(y_battery,y_battery_pred),
    "y_charge":(y_charge,y_charge_pred),
    "y_house":(y_house,y_house_pred),
    "y_electric":(y_electric,y_electric_pred),
    "y_pump":(y_pump,y_pump_pred),
    "y_consumer":(y_consumer,y_consumer_pred),
    "y_soc":(y_soc,y_soc_pred),
    "y_tpow_battery":(y_tpow_battery,y_tpow_battery_pred),
    "y_tpow_charge":(y_tpow_charge,y_tpow_charge_pred),
    "y_tpow_electric":(y_tpow_electric,y_tpow_electric_pred),
    "y_tpow_pump":(y_tpow_pump,y_tpow_pump_pred),
    "y_tpow_consumer":(y_tpow_consumer,y_tpow_consumer_pred)
    }
    
metrics = {
    "MAPE": {"metric": mean_absolute_percentage_error, "limit": 1},
    "Corr": {"metric": np.corrcoef},
    "MAE": {"metric": mean_absolute_error},
    # "R2": {"metric": r2_score} prone to outliers
    
    }    



# Calc error measures
error_dict = dict()
for mkey, mval in metrics.items():
    model_errors = pairs.copy()
    mean = 0
    count = 0

    for key, val in model_errors.items():
        if len(val[0]) == 0:
            model_errors[key] = -99
        else:
            if key != "y_consumption":
                error = 0
                instance_count = 0
                for instance in range(0, len(val[0])):
                    count+=1
                    instance_count += 1
                    er = mval["metric"](val[0][instance], val[1][instance])
                    if mkey == "Corr":
                        er = er[0,1]
                    
                    if "limit" in mval.keys():
                        if er > mval["limit"]:
                            er = mval["limit"]
                    error+=er
                    mean+=er
                error = error/instance_count
            else:
                count+=1
                error = mval["metric"](val[0], val[1])
                if mkey == "Corr":
                        error = error[0,1]
                
                if "limit" in mval.keys():
                    if error > mval["limit"]:
                        error = mval["limit"]
                mean+=error

            model_errors[key] = error
    
    model_errors["mean"] = mean/count
            
    model_errors = {key: value for key, value in model_errors.items() if value != -99}
    error_dict[mkey] = model_errors


    import seaborn as sns
import matplotlib.pyplot as plt

# Plot errors

fig, axes = plt.subplots(nrows=1, ncols=len(error_dict), figsize=(18, 6), sharey=False)
for i, (key, value) in enumerate(error_dict.items()):
    
    # Extract keys and values from the dictionary
    model_names = list(value.keys())
    errors = list(value.values())

    # Create a bar chart using seaborn
    sns.set(style="white")
    plt.figure(figsize=(10, 6))
    axes[i].set_title(f'{model_df.iloc[index]["project_name"]} {key} {train_duration_weeks}-weeks')
    
    palette = [
'#03e0b5',
'#24AD92',
'#327A6C',
'#2C4742',
'#293331',]
    # You can customize the color palette if needed
    ax = sns.barplot(x=model_names, ax=axes[i], y=errors, palette=palette, hue=errors)
    ax.legend_.remove()
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
    for p in ax.patches:
        if p.get_width() == p.get_height() == 0:
            continue
        
        ax.text(p.get_x() + p.get_width()/2., p.get_height(), '{0:.2f}'.format(p.get_height()), 
        fontsize=12, color=p.get_facecolor(), ha='center', va='bottom')

fig.savefig(f"XGBOOST{model_df.iloc[index]['project_name']}_{model_df.iloc[index]['model_id']}_dur-{train_duration_weeks}.png")
# Out:
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_42136\3990312490.py:123: UserWarning:
# The palette list has fewer values (5) than needed (8) and will cycle, which may produce an uninterpretable plot.
#   ax = sns.barplot(x=model_names, ax=axes[i], y=errors, palette=palette, hue=errors)
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_42136\3990312490.py:125: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_42136\3990312490.py:123: UserWarning:
# The palette list has fewer values (5) than needed (10) and will cycle, which may produce an uninterpretable plot.
#   ax = sns.barplot(x=model_names, ax=axes[i], y=errors, palette=palette, hue=errors)
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_42136\3990312490.py:125: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_42136\3990312490.py:123: UserWarning:
# The palette list has fewer values (5) than needed (10) and will cycle, which may produce an uninterpretable plot.
#   ax = sns.barplot(x=model_names, ax=axes[i], y=errors, palette=palette, hue=errors)
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_42136\3990312490.py:125: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')

# %% [markdown]
# ### OLD

# %%
# create test set and predict

df_test = model_holder.get_dh().get_data(int(end_training.timestamp()), int(end.timestamp()))
df_test = preprocess_ems_data(df_test, 15, True)

(x, y_consumption, y_pv, y_generator, y_grid, y_battery,
    y_charge, y_house, y_electric, y_pump, y_consumer,
    y_soc, y_tpow_battery, y_tpow_charge, y_tpow_electric, y_tpow_pump,
    y_tpow_consumer, recursive) = get_ems_features(
    df_test,
    lag_steps=[15, 30, 45, 60],
    prediction_steps=[15, 30, 45, 60],
    time_resolution=15,
    lag_label=[15])
    
(y_consumption_pred, y_pv_pred, y_generator_pred, y_grid_pred, y_battery_pred, y_charge_pred,
    y_house_pred, y_electric_pred, y_pump_pred, y_consumer_pred, y_soc_pred, y_tpow_battery_pred,
    y_tpow_charge_pred, y_tpow_electric_pred, y_tpow_pump_pred, y_tpow_consumer_pred) = model.predict(x, recursive)
    
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error, r2_score
import numpy as np

# prepare error calcs
pairs = {
    "y_consumption":(y_consumption,y_consumption_pred),
    "y_pv":(y_pv,y_pv_pred),
    "y_generator":(y_generator,y_generator_pred),
    "y_grid":(y_grid,y_grid_pred),
    "y_battery":(y_battery,y_battery_pred),
    "y_charge":(y_charge,y_charge_pred),
    "y_house":(y_house,y_house_pred),
    "y_electric":(y_electric,y_electric_pred),
    "y_pump":(y_pump,y_pump_pred),
    "y_consumer":(y_consumer,y_consumer_pred),
    "y_soc":(y_soc,y_soc_pred),
    "y_tpow_battery":(y_tpow_battery,y_tpow_battery_pred),
    "y_tpow_charge":(y_tpow_charge,y_tpow_charge_pred),
    "y_tpow_electric":(y_tpow_electric,y_tpow_electric_pred),
    "y_tpow_pump":(y_tpow_pump,y_tpow_pump_pred),
    "y_tpow_consumer":(y_tpow_consumer,y_tpow_consumer_pred)
    }
    
metrics = {
    "MAPE": {"metric": mean_absolute_percentage_error, "limit": 1},
    "Corr": {"metric": np.corrcoef},
    "MAE": {"metric": mean_absolute_error},
    # "R2": {"metric": r2_score} prone to outliers
    
    }

# %%
# Calc error measures
error_dict = dict()
for mkey, mval in metrics.items():
    model_errors = pairs.copy()
    mean = 0
    count = 0

    for key, val in model_errors.items():
        if len(val[0]) == 0:
            model_errors[key] = -99
        else:
            if key != "y_consumption":
                error = 0
                instance_count = 0
                for instance in range(0, len(val[0])):
                    count+=1
                    instance_count += 1
                    er = mval["metric"](val[0][instance], val[1][instance])
                    if mkey == "Corr":
                        er = er[0,1]
                    
                    if "limit" in mval.keys():
                        if er > mval["limit"]:
                            er = mval["limit"]
                    error+=er
                    mean+=er
                error = error/instance_count
            else:
                count+=1
                error = mval["metric"](val[0], val[1])
                if mkey == "Corr":
                        error = error[0,1]
                
                if "limit" in mval.keys():
                    if error > mval["limit"]:
                        error = mval["limit"]
                mean+=error

            model_errors[key] = error
    
    model_errors["mean"] = mean/count
            
    model_errors = {key: value for key, value in model_errors.items() if value != -99}
    error_dict[mkey] = model_errors

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot errors

fig, axes = plt.subplots(nrows=1, ncols=len(error_dict), figsize=(18, 6), sharey=False)
for i, (key, value) in enumerate(error_dict.items()):
    
    # Extract keys and values from the dictionary
    model_names = list(value.keys())
    errors = list(value.values())

    # Create a bar chart using seaborn
    sns.set(style="white")
    plt.figure(figsize=(10, 6))
    axes[i].set_title(f'{model_df.iloc[index]["project_name"]} {key} {train_duration_weeks}-weeks')
    
    palette = [
'#03e0b5',
'#24AD92',
'#327A6C',
'#2C4742',
'#293331',]
    # You can customize the color palette if needed
    ax = sns.barplot(x=model_names, ax=axes[i], y=errors, palette=palette, hue=errors)
    ax.legend_.remove()
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
    for p in ax.patches:
        if p.get_width() == p.get_height() == 0:
            continue
        
        ax.text(p.get_x() + p.get_width()/2., p.get_height(), '{0:.2f}'.format(p.get_height()), 
        fontsize=12, color=p.get_facecolor(), ha='center', va='bottom')

fig.savefig(f"XGBOOST{model_df.iloc[index]['project_name']}_{model_df.iloc[index]['model_id']}_dur-{train_duration_weeks}.png")
# Out:
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_36244\822438491.py:25: UserWarning:
# The palette list has fewer values (5) than needed (9) and will cycle, which may produce an uninterpretable plot.
#   ax = sns.barplot(x=model_names, ax=axes[i], y=errors, palette=palette, hue=errors)
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_36244\822438491.py:27: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_36244\822438491.py:25: UserWarning:
# The palette list has fewer values (5) than needed (10) and will cycle, which may produce an uninterpretable plot.
#   ax = sns.barplot(x=model_names, ax=axes[i], y=errors, palette=palette, hue=errors)
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_36244\822438491.py:27: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_36244\822438491.py:25: UserWarning:
# The palette list has fewer values (5) than needed (10) and will cycle, which may produce an uninterpretable plot.
#   ax = sns.barplot(x=model_names, ax=axes[i], y=errors, palette=palette, hue=errors)
# C:\Users\jpeff\AppData\Local\Temp\ipykernel_36244\822438491.py:27: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
